# %%
import pandas as pd,numpy as np

# %%
rating=pd.read_csv('ratings.csv')

# %%
rating.shape
# Out:
# (100836, 4)

# %%
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
rating['userId'].nunique()
# Out:
# 610

# %%
rating['rating'].max()
# Out:
# 5.0

# %%
rating[rating['rating']==5.0]
# Out:
#         userId  movieId  rating   timestamp
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 6            1      101     5.0   964980868
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# ...        ...      ...     ...         ...
# 100814     610   158238     5.0  1479545219
# 100829     610   164179     5.0  1493845631
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [13211 rows x 4 columns]

# %%
mov=pd.read_csv('movies.csv')

# %%
mov.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
mov[mov['movieId']==47]
# Out:
#     movieId                        title            genres
# 43       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller

# %%
df=pd.merge(mov,rating,on='movieId')
df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df[df['rating']==5.0].head(20)
# Out:
#     movieId             title                                       genres  \
# 9         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 12        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 13        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 16        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 19        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 20        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 24        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 34        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 50        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 51        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 58        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
df.title.unique()
# Out:
# array(['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)',
#        ..., 'Flint (2017)', 'Bungo Stray Dogs: Dead Apple (2018)',
#        'Andrew Dice Clay: Dice Rules (1991)'], dtype=object)

# %%
a=df[df['title']=="Terminator 2: Judgment Day (1991)"]
a
# Out:
#        movieId                              title         genres  userId  \
# 15651      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       5
# 15652      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       6
# 15653      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       7
# 15654      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 15655      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# ...        ...                                ...            ...     ...
# 15870      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     606
# 15871      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 15872      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     608
# 15873      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     609
# 15874      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
#
#        rating   timestamp
# 15651     3.0   847435258
# 15652     3.0   845553317
# ...

# %%
a.rating.mean()
# Out:
# 3.970982142857143

# %%
b=df[df['title']== "Matrix, The (1999)"]
b.rating.mean()
# Out:
# 4.192446043165468

# %%
b=df[df['title']== "Pulp Fiction (1994)"]
b.rating.mean()
# Out:
# 4.197068403908795

# %%
b=df[df['title']== "Forrest Gump (1994)"]
b.rating.mean()
# Out:
# 4.164133738601824

# %%
b=df[df['title']== "Shawshank Redemption, The (1994)"]
b.rating.mean()
# Out:
# 4.429022082018927

# %%
df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
mov
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
tag=pd.read_csv('tags.csv')
tag
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df1=pd.merge(mov,tag,on= 'movieId')
df1
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
df1[df1['title']=="Matrix, The (1999)"]
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
a=df[df['title']=="Fight Club (1999)"]

# %%
import seaborn as sns ,matplotlib.pyplot as plt

# %%
sns.histplot(a,x='rating')
# Out:
# C:\Users\91949\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='rating', ylabel='Count'>

# %%
sns.kdeplot(a,x='rating')
# Out:
# C:\Users\91949\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='rating', ylabel='Density'>

# %%
c=df[df['title']== "Godfather, The (1972)"]
c.rating.mean()
# Out:
# 4.2890625

# %%
c=df[df['title']== "Shawshank Redemption, The (1994)"]
c.rating.mean()
# Out:
# 4.429022082018927

# %%
c=df[df['title']== "Jumanji (1995)"]
c.rating.mean()
# Out:
# 3.4318181818181817

# %%
c=df[df['title']== "Wolf of Wall Street, The (2013)"]
c.rating.mean()
# Out:
# 3.9166666666666665

# %%
df[df['rating']==5.0].head(20)
# Out:
#     movieId             title                                       genres  \
# 9         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 12        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 13        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 16        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 19        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 20        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 24        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 34        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 50        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 51        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 58        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
d=df[df['title']== "Pulp Fiction (1994)"
d.rating.mean()

# %%
lin=pd.read_csv('links.csv')

# %%
lin
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
df['rating'].sort_values(ascending=False).head(10)
# Out:
# 56251    5.0
# 33888    5.0
# 20742    5.0
# 10168    5.0
# 10169    5.0
# 65379    5.0
# 10171    5.0
# 20739    5.0
# 10173    5.0
# 10174    5.0
# Name: rating, dtype: float64

# %%
df[df['movieId']==56251]
# Out:
#        movieId                                title                   genres  \
# 86327    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86328    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86329    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86330    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86331    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86332    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86333    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86334    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86335    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
# 86336    56251  Futurama: Bender's Big Score (2007)  Animation|Comedy|Sci-Fi
#
#        userId  rating   timestamp
# 86327      68     4.0  1261624311
# 86328     177     3.5  1435804548
# ...

# %%
df.dtypes
# Out:
# movieId        int64
# title         object
# genres        object
# userId         int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
lin.imdbId.max()
# Out:
# 8391976

# %%
lin[lin.imdbId==8391976]
# Out:
#       movieId   imdbId    tmdbId
# 9740   193587  8391976  483455.0

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
sci_fi_movies = df[df['genres'].str.contains('Sci-Fi', case=False, na=False)]

# Merge with links to get IMDb IDs
sci_fi_movies_links = sci_fi_movies.merge(lin, on='movieId')

# %%
sci_fi_movies_links
# Out:
#        movieId                        title  \
# 0           24                Powder (1995)
# 1           24                Powder (1995)
# 2           24                Powder (1995)
# 3           24                Powder (1995)
# 4           24                Powder (1995)
# ...        ...                          ...
# 17238   188301  Ant-Man and the Wasp (2018)
# 17239   189547          Iron Soldier (2010)
# 17240   190183     The Darkest Minds (2018)
# 17241   191005               Gintama (2017)
# 17242   193565    Gintama: The Movie (2010)
#
#                                        genres  userId  rating   timestamp  \
# 0                                Drama|Sci-Fi       6     4.0   845554397
# 1                                Drama|Sci-Fi      32     3.0   856737205
# 2                                Drama|Sci-Fi      71     2.0   864740028
# 3                                Drama|Sci-Fi     111     2.5  1518640854
# ...

# %%
sci_fi_movies.shape
# Out:
# (980, 3)

# %%
df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
sci_fi_movies_links[sci_fi_movies_links.rating==5.0]
# Out:
#        movieId                                              title  \
# 7           24                                      Powder (1995)
# 14          24                                      Powder (1995)
# 22          24                                      Powder (1995)
# 29          29  City of Lost Children, The (Cité des enfants p...
# 32          29  City of Lost Children, The (Cité des enfants p...
# ...        ...                                                ...
# 17218   187593                                  Deadpool 2 (2018)
# 17220   187593                                  Deadpool 2 (2018)
# 17223   187593                                  Deadpool 2 (2018)
# 17224   187593                                  Deadpool 2 (2018)
# 17234   187595                     Solo: A Star Wars Story (2018)
#
#                                        genres  userId  rating   timestamp  \
# 7                                Drama|Sci-Fi     234     5.0  1004407893
# ...

# %%
df[df.rat
# Out:
#         movieId                             title  \
# 9             1                  Toy Story (1995)
# 12            1                  Toy Story (1995)
# 13            1                  Toy Story (1995)
# 16            1                  Toy Story (1995)
# 19            1                  Toy Story (1995)
# ...         ...                               ...
# 100787   187593                 Deadpool 2 (2018)
# 100790   187593                 Deadpool 2 (2018)
# 100791   187593                 Deadpool 2 (2018)
# 100801   187595    Solo: A Star Wars Story (2018)
# 100802   187717  Won't You Be My Neighbor? (2018)
#
#                                              genres  userId  rating  \
# 9       Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# 12      Adventure|Animation|Children|Comedy|Fantasy      40     5.0
# 13      Adventure|Animation|Children|Comedy|Fantasy      43     5.0
# 16      Adventure|Animation|Children|Comedy|Fantasy      46     5.0
# ...

# %%
df2=pd.merge(df,lin,on='movieId')

# %%
df2
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...
